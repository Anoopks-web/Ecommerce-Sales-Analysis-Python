# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/online_retail_II(1).csv")

# %%
df
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#                 InvoiceDate  Price  Customer ID         Country
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525461 entries, 0 to 525460
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      525461 non-null  object
#  1   StockCode    525461 non-null  object
#  2   Description  522533 non-null  object
#  3   Quantity     525461 non-null  int64
#  4   InvoiceDate  525461 non-null  object
#  5   Price        525461 non-null  float64
#  6   Customer ID  417534 non-null  float64
#  7   Country      525461 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 32.1+ MB

# %%
df.columns
# Out:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country'],
#       dtype='object')

# %%
df.shape
# Out:
# (525461, 8)

# %%
df.isnull().sum()
# Out:
# Invoice             0
# StockCode           0
# Description      2928
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    107927
# Country             0
# dtype: int64

# %%
df.isnull()
# Out:
#         Invoice  StockCode  Description  Quantity  InvoiceDate  Price  \
# 0         False      False        False     False        False  False
# 1         False      False        False     False        False  False
# 2         False      False        False     False        False  False
# 3         False      False        False     False        False  False
# 4         False      False        False     False        False  False
# ...         ...        ...          ...       ...          ...    ...
# 525456    False      False        False     False        False  False
# 525457    False      False        False     False        False  False
# 525458    False      False        False     False        False  False
# 525459    False      False        False     False        False  False
# 525460    False      False        False     False        False  False
#
#         Customer ID  Country
# 0             False    False
# 1             False    False
# 2             False    False
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(6865)

# %%
df[df.duplicated()]
# Out:
#        Invoice StockCode                        Description  Quantity  \
# 371     489517     21912           VINTAGE SNAKES & LADDERS         1
# 383     489517     22130   PARTY CONE CHRISTMAS DECORATION          6
# 384     489517     22319  HAIRCLIPS FORTIES FABRIC ASSORTED        12
# 385     489517     21913     VINTAGE SEASIDE JIGSAW PUZZLES         1
# 386     489517     21821   GLITTER STAR GARLAND WITH BELLS          1
# ...        ...       ...                                ...       ...
# 523258  538035     20728                LUNCH BAG CARS BLUE         3
# 523356  538051     22659            LUNCH BOX I LOVE LONDON         2
# 525170  538155     21907          I'M ON HOLIDAY METAL SIGN         1
# 525293  538166     21915             RED  HARMONICA IN BOX          5
# 525340  538168     22739  RIBBON REEL CHRISTMAS SOCK BAUBLE         5
#
#                 InvoiceDate  Price  Customer ID         Country
# ...

# %%
# Display the first 5 rows.
df.head(5)
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country
# 0  12/01/2009 07:45:00   6.95      13085.0  United Kingdom
# 1  12/01/2009 07:45:00   6.75      13085.0  United Kingdom
# 2  12/01/2009 07:45:00   6.75      13085.0  United Kingdom
# 3  12/01/2009 07:45:00   2.10      13085.0  United Kingdom
# 4  12/01/2009 07:45:00   1.25      13085.0  United Kingdom

# %%
# Display the last 5 rows.
df.tail(5)
# Out:
#        Invoice StockCode                         Description  Quantity  \
# 525456  538171     22271                FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750        FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751      FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970  PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931              JUMBO STORAGE BAG SUKI         2
#
#                 InvoiceDate  Price  Customer ID         Country
# 525456  12/09/2010 20:01:00   2.95      17530.0  United Kingdom
# 525457  12/09/2010 20:01:00   3.75      17530.0  United Kingdom
# 525458  12/09/2010 20:01:00   3.75      17530.0  United Kingdom
# 525459  12/09/2010 20:01:00   3.75      17530.0  United Kingdom
# 525460  12/09/2010 20:01:00   1.95      17530.0  United Kingdom

# %%
# Find the number of rows and columns.
df.shape
# Out:
# (525461, 8)

# %%
# Display all column names.
df.columns
# Out:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country'],
#       dtype='object')

# %%
# Check the data types of each column.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525461 entries, 0 to 525460
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      525461 non-null  object
#  1   StockCode    525461 non-null  object
#  2   Description  522533 non-null  object
#  3   Quantity     525461 non-null  int64
#  4   InvoiceDate  525461 non-null  object
#  5   Price        525461 non-null  float64
#  6   Customer ID  417534 non-null  float64
#  7   Country      525461 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 32.1+ MB

# %%
# Generate descriptive statistics.
df.describe()
# Out:
#             Quantity          Price    Customer ID
# count  525461.000000  525461.000000  417534.000000
# mean       10.337667       4.688834   15360.645478
# std       107.424110     146.126914    1680.811316
# min     -9600.000000  -53594.360000   12346.000000
# 25%         1.000000       1.250000   13983.000000
# 50%         3.000000       2.100000   15311.000000
# 75%        10.000000       4.210000   16799.000000
# max     19152.000000   25111.090000   18287.000000

# %%
# Find the number of missing values in each column.
df.isnull().sum().sum()
# Out:
# np.int64(110855)

# %%
# 9. Missing-value percentage
print((df.isnull().sum() / len(df) * 100).sort_values(ascending=False))
# Out:
# Customer ID    20.539488
# Description     0.557225
# StockCode       0.000000
# Invoice         0.000000
# Quantity        0.000000
# InvoiceDate     0.000000
# Price           0.000000
# Country         0.000000
# dtype: float64

# %%
# Check for duplicate records.
df = df.drop_duplicates()
df
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#                 InvoiceDate  Price  Customer ID         Country
# ...

# %%
# Remove duplicate records.
df = df.drop_duplicates()
df
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#                 InvoiceDate  Price  Customer ID         Country
# ...

# %%
# Convert InvoiceDate to datetime.
df['InvoiceDate']=pd.to_datetime(df['InvoiceDate'])
df
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#                InvoiceDate  Price  Customer ID         Country
# ...

# %%
# Check the earliest transaction date.
print(df['InvoiceDate'].min())
# Out:
# 2009-12-01 07:45:00

# %%
# Check the latest transaction date.
print(df['InvoiceDate'].max())
# Out:
# 2010-12-09 20:01:00

# %%
# Find the number of unique invoices.
print(df['Invoice'].unique())
number_of_uniqueinvoice=df['Invoice'].nunique()
print('number_of_uniqueinvoice:',number_of_uniqueinvoice)
# Out:
# ['489434' '489435' '489436' ... '538169' '538170' '538171']
# number_of_uniqueinvoice: 28816

# %%
df.columns
# Out:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country'],
#       dtype='object')

# %%
# Find the number of unique customers.
no_of_customers=df['Customer ID'].nunique()
print(no_of_customers)
# Out:
# 4383

# %%
# Find the number of unique products.
noofuniqueproducts=df['StockCode'].nunique()
print(noofuniqueproducts)
# Out:
# 4632

# %%
# Find the number of countries.
country=df['Country'].nunique()
print(country)
# Out:
# 40

# %%
df
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#                InvoiceDate  Price  Customer ID         Country
# ...

# %%
#. Cancelled invoices
cancelled = df["Invoice"].astype(str).str.startswith("C")
print(cancelled.sum())
# Out:
# 10182

# %%
# Check negative quantities.
(df['Quantity']<0).sum()
# Out:
# np.int64(12302)

# %%
# Create cancellation flag
df["Cancelled"] = df["Invoice"].astype(str).str.startswith("C")
# Create Revenue
df["Revenue"] = df["Quantity"] * df["Price"]
# Completed sales
sales_df = df[
    (df["Cancelled"] == False) &
    (df["Quantity"] > 0) &
    (df["Price"] > 0)
].copy()
print(sales_df.shape)
# Out:
# (504730, 10)

# %%
# Calculate total quantity sold.
total_sold=sales_df['Quantity'].sum()
print(total_sold)
# Out:
# 5812947

# %%
sales_df.columns
# Out:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country', 'Cancelled', 'Revenue'],
#       dtype='object')

# %%
# Calculate total revenue.
total_revune=sales_df['Revenue'].sum()
print(total_revune)
# Out:
# 10271762.664

# %%
# Calculate average unit price.
avgunitprice=sales_df['Price'].mean()
print(avgunitprice)
# Out:
# 4.273960125215462

# %%
# Calculate average order value.
order_value=sales_df.groupby("Invoice")['Revenue'].sum()
avg_order_value=order_value.mean()
print(avg_order_value)
# Out:
# 490.27553166913276

# %%
# Find the highest-value transaction.
higest_order=sales_df['Revenue'].sort_values(ascending=False).head(1)
higest_order
# Out:
# 241827    25111.09
# Name: Revenue, dtype: float64

# %%
# Find the lowest-value transaction.
print(sales_df.loc[sales_df["Revenue"].idxmin()])
# Out:
# Invoice                            494914
# StockCode                            PADS
# Description    PADS TO MATCH ALL CUSHIONS
# Quantity                                1
# InvoiceDate           2010-01-19 17:04:00
# Price                               0.001
# Customer ID                       16705.0
# Country                    United Kingdom
# Cancelled                           False
# Revenue                             0.001
# Name: 62299, dtype: object

# %%
# Find the most frequently sold product.
print(sales_df["Description"].value_counts().head(1))
# Out:
# Description
# WHITE HANGING HEART T-LIGHT HOLDER    3409
# Name: count, dtype: int64

# %%
# Find the product generating the highest revenue.
revunecategory=sales_df.groupby('Description')['Revenue'].sum()
revunecategory.sort_values(ascending=False).head(1)
# Out:
# Description
# Manual    262589.86
# Name: Revenue, dtype: float64

# %%
# Find the top 10 products by quantity.
categoryquantity=sales_df.groupby("Description")['Quantity'].sum()
top10category=categoryquantity.sort_values(ascending=False).head(10)
print(top10category)
# Out:
# Description
# WHITE HANGING HEART T-LIGHT HOLDER    58691
# WORLD WAR 2 GLIDERS ASSTD DESIGNS     54947
# BROCADE RING PURSE                    48374
# PACK OF 72 RETRO SPOT CAKE CASES      46728
# ASSORTED COLOUR BIRD ORNAMENT         45228
# 60 TEATIME FAIRY CAKE CASES           36348
# PACK OF 60 PINK PAISLEY CAKE CASES    31805
# JUMBO BAG RED RETROSPOT               30746
# SMALL POPCORN HOLDER                  29773
# STRAWBERRY CERAMIC TRINKET BOX        27059
# Name: Quantity, dtype: int64

# %%
# Find the top 10 products by revenue.
customer_revune=sales_df.groupby("Customer ID")['Revenue'].sum()
top10=customer_revune.sort_values(ascending=False).head(10)
top10
# Out:
# Customer ID
# 18102.0    349164.35
# 14646.0    248396.50
# 14156.0    196549.74
# 14911.0    152121.22
# 13694.0    131443.19
# 17511.0     84541.17
# 15061.0     83284.38
# 16684.0     80489.21
# 16754.0     65500.07
# 17949.0     60117.60
# Name: Revenue, dtype: float64

# %%
# Find the bottom 10 products by revenue.
productrevune=sales_df.groupby('Description')['Revenue'].sum()
bottom10=productrevune.sort_values(ascending=False).tail(10)
print(bottom10)
# Out:
# Description
# HAPPY BIRTHDAY CARD TEDDY/CAKE        0.950
# UBO-LIGHT TRIOBASE BLUE               0.850
# OWLS CHARLOTTE BAG                    0.850
# BLUE WHITE PLASTIC RINGS LAMPSHADE    0.850
# CAT W SUNGLASSES BLANK CARD           0.760
# SILICON CUBE 25W, BLUE                0.420
# HAPPY BIRTHDAY GINGER CAT CARD        0.380
# CHAMPAGNE TRAY BLANK CARD             0.380
# PINK HEART CHRISTMAS DECORATION       0.380
# PADS TO MATCH ALL CUSHIONS            0.014
# Name: Revenue, dtype: float64

# %%
# Calculate revenue for each product.
prodcutrevune=sales_df.groupby("Description")['Revenue'].sum()
prodcutrevune
# Out:
# Description
#   DOORMAT UNION JACK GUNS AND ROSES     1193.31
#  3 STRIPEY MICE FELTCRAFT               1342.03
#  4 PURPLE FLOCK DINNER CANDLES           298.11
#  ANIMAL STICKERS                          80.85
#  BLACK PIRATE TREASURE CHEST             108.48
#                                          ...
# ZINC HEART LATTICE TRAY OVAL             376.02
# ZINC METAL HEART DECORATION            17145.10
# ZINC POLICE BOX LANTERN                  806.22
# ZINC TOP  2 DOOR WOODEN SHELF           1461.35
# ZINC WILLIE WINKIE  CANDLE STICK        3516.28
# Name: Revenue, Length: 4534, dtype: float64

# %%
# Calculate quantity sold for each product.
productquantity=sales_df.groupby("Description")['Quantity'].sum()
productquantity
# Out:
# Description
#   DOORMAT UNION JACK GUNS AND ROSES      177
#  3 STRIPEY MICE FELTCRAFT                691
#  4 PURPLE FLOCK DINNER CANDLES           207
#  ANIMAL STICKERS                         385
#  BLACK PIRATE TREASURE CHEST              55
#                                        ...
# ZINC HEART LATTICE TRAY OVAL             326
# ZINC METAL HEART DECORATION            14120
# ZINC POLICE BOX LANTERN                  195
# ZINC TOP  2 DOOR WOODEN SHELF            237
# ZINC WILLIE WINKIE  CANDLE STICK        3950
# Name: Quantity, Length: 4534, dtype: int64

# %%
product_avg_price = sales_df.groupby("Description")["Price"].mean()
print(product_avg_price)
# Out:
# Description
#   DOORMAT UNION JACK GUNS AND ROSES     7.452333
#  3 STRIPEY MICE FELTCRAFT               2.188788
#  4 PURPLE FLOCK DINNER CANDLES          2.584762
#  ANIMAL STICKERS                        0.210000
#  BLACK PIRATE TREASURE CHEST            2.375000
#                                          ...
# ZINC HEART LATTICE TRAY OVAL            5.971364
# ZINC METAL HEART DECORATION             1.387674
# ZINC POLICE BOX LANTERN                 7.395000
# ZINC TOP  2 DOOR WOODEN SHELF          12.159091
# ZINC WILLIE WINKIE  CANDLE STICK        1.085273
# Name: Price, Length: 4534, dtype: float64

# %%
# Find products with revenue above the average product revenue.
prodcutrevune=sales_df.groupby("Description")['Revenue'].sum()
avgrevune=prodcutrevune.mean()
print(avgrevune)
# Out:
# 2265.4968381120425

# %%
# Find the percentage contribution of each product to total revenue.
totalrevune=sales_df['Revenue'].sum()
prodcutrevune=sales_df.groupby("Description")['Revenue'].sum()
contribution=(prodcutrevune/totalrevune)
print(contribution.sort_values(ascending=False))
# Out:
# Description
# Manual                                2.556425e-02
# REGENCY CAKESTAND 3 TIER              1.654173e-02
# WHITE HANGING HEART T-LIGHT HOLDER    1.561033e-02
# DOTCOM POSTAGE                        1.133289e-02
# ASSORTED COLOUR BIRD ORNAMENT         7.096172e-03
#                                           ...
# SILICON CUBE 25W, BLUE                4.088880e-08
# HAPPY BIRTHDAY GINGER CAT CARD        3.699462e-08
# CHAMPAGNE TRAY BLANK CARD             3.699462e-08
# PINK HEART CHRISTMAS DECORATION       3.699462e-08
# PADS TO MATCH ALL CUSHIONS            1.362960e-09
# Name: Revenue, Length: 4534, dtype: float64

# %%
# Find the number of products sold in each country.
totalsoldproducts=sales_df.groupby("Country")['Quantity'].sum()
totalsoldproducts
# Out:
# Country
# Australia                 20189
# Austria                    6697
# Bahrain                    1025
# Belgium                   12059
# Bermuda                    2798
# Brazil                      189
# Canada                      894
# Channel Islands           11991
# Cyprus                     4610
# Denmark                  229690
# EIRE                     193047
# Finland                    3671
# France                   163029
# Germany                  108615
# Greece                     6167
# Hong Kong                  2308
# Iceland                     828
# Israel                     1132
# Italy                      7364
# Japan                      7311
# Korea                       700
# Lebanon                      72
# Lithuania                  2306
# Malta                      1549
# Netherlands              183615
# Nigeria                     103
# Norway                     7867
# Poland                     2144
# Portugal                  12148
# ...

# %%
# Identify products with unusually high quantities.
product_quantity=sales_df.groupby("Description")['Quantity'].sum()
quantity_threshold = product_quantity.mean() + 3 * product_quantity.std()

print(
    product_quantity[
        product_quantity > quantity_threshold
    ].sort_values(ascending=False)
)
print()
# Out:
# Description
# WHITE HANGING HEART T-LIGHT HOLDER    58691
# WORLD WAR 2 GLIDERS ASSTD DESIGNS     54947
# BROCADE RING PURSE                    48374
# PACK OF 72 RETRO SPOT CAKE CASES      46728
# ASSORTED COLOUR BIRD ORNAMENT         45228
#                                       ...
# MULTICOLOUR SPRING FLOWER MUG         11130
# HEART OF WICKER SMALL                 11050
# JAZZ HEARTS MEMO PAD                  10967
# WRAP PINK FAIRY CAKES                 10961
# PLEASE ONE PERSON METAL SIGN          10887
# Name: Quantity, Length: 85, dtype: int64

# %%
# Identify products with unusually high prices.
avg_price = sales_df.groupby("Description")["Price"].mean()

price_threshold = avg_price.mean() + 3 * avg_price.std()

print(
    avg_price[
        avg_price > price_threshold
    ].sort_values(ascending=False)
)
print(price_threshold )
# Out:
# Description
# AMAZON FEE    10124.020000
# Manual          470.254079
# Name: Price, dtype: float64
# 459.7858850885492

# %% [markdown]
# Customer Analysis

# %%
sales_df.columns
# Out:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country', 'Cancelled', 'Revenue'],
#       dtype='object')

# %%
# Calculate total spending for each customer.
customer_spend=sales_df.groupby("Customer ID")['Revenue'].sum()
print(customer_spend)
# Out:
# Customer ID
# 12346.0     372.86
# 12347.0    1323.32
# 12348.0     222.16
# 12349.0    2671.14
# 12351.0     300.93
#             ...
# 18283.0     619.37
# 18284.0     461.68
# 18285.0     427.00
# 18286.0    1296.43
# 18287.0    2345.71
# Name: Revenue, Length: 4312, dtype: float64

# %%
# Find the top 10 highest-spending customers.
customer_spend=sales_df.groupby("Customer ID")['Revenue'].sum()
top10=customer_spend.sort_values(ascending=False).head(10)
print(top10)
# Out:
# Customer ID
# 18102.0    349164.35
# 14646.0    248396.50
# 14156.0    196549.74
# 14911.0    152121.22
# 13694.0    131443.19
# 17511.0     84541.17
# 15061.0     83284.38
# 16684.0     80489.21
# 16754.0     65500.07
# 17949.0     60117.60
# Name: Revenue, dtype: float64

# %%
# Find the customer with the highest spending.
customer_spend=sales_df.groupby("Customer ID")['Revenue'].sum()
topcustomer=customer_spend.sort_values(ascending=False).head(1)
print(topcustomer)
# Out:
# Customer ID
# 18102.0    349164.35
# Name: Revenue, dtype: float64

# %%
# most order customer
customer_orders = sales_df.groupby("Customer ID")['Invoice'].nunique()
most_order_customer = customer_orders.sort_values(ascending=False).head(1)
print(most_order_customer)
# Out:
# Customer ID
# 14911.0    205
# Name: Invoice, dtype: int64

# %%
# Find the average customer spending.
customer_spend=sales_df.groupby("Customer ID")['Revenue'].sum()
avg_spend=customer_spend.mean()
print(avg_spend)
# Out:
# 2040.4067124304265

# %%
# Find the average number of orders per customer.
customer_orders = sales_df.groupby("Customer ID")['Invoice'].nunique()
avg_order=customer_orders.mean()
print(avg_order)
# Out:
# 4.455705009276437

# %%
# Find customers who spent more than the average customer.
cavg_spend=customer_spend.mean()
print(customer_spend[customer_spend>avg_spend])
# Out:
# Customer ID
# 12349.0     2671.14
# 12356.0     3560.30
# 12357.0    12079.99
# 12358.0     2719.01
# 12359.0     2563.36
#              ...
# 18251.0    21964.14
# 18257.0     2262.52
# 18258.0     2059.67
# 18260.0     7318.91
# 18287.0     2345.71
# Name: Revenue, Length: 911, dtype: float64

# %%
# Find customers who placed more than 10 orders.
customer_orders = sales_df.groupby("Customer ID")['Invoice'].nunique()
print(customer_orders[customer_orders>10])
# Out:
# Customer ID
# 12346.0    11
# 12417.0    11
# 12422.0    14
# 12431.0    13
# 12437.0    21
#            ..
# 18225.0    15
# 18226.0    15
# 18231.0    23
# 18245.0    13
# 18260.0    17
# Name: Invoice, Length: 335, dtype: int64

# %%
# Find one-time customers.
onetimecustomer=customer_orders[customer_orders==1]
print(onetimecustomer)
# Out:
# Customer ID
# 12348.0    1
# 12351.0    1
# 12353.0    1
# 12355.0    1
# 12362.0    1
#           ..
# 18279.0    1
# 18280.0    1
# 18281.0    1
# 18284.0    1
# 18285.0    1
# Name: Invoice, Length: 1419, dtype: int64

# %%
# Find repeat customers.
repeat_customer=customer_orders[customer_orders>1]
print(repeat_customer)
# Out:
# Customer ID
# 12346.0    11
# 12347.0     2
# 12349.0     3
# 12352.0     2
# 12356.0     3
#            ..
# 18276.0     5
# 18277.0     4
# 18283.0     6
# 18286.0     2
# 18287.0     4
# Name: Invoice, Length: 2893, dtype: int64

# %%
# Calculate revenue contribution by customer.
total_revune=sales_df['Revenue'].sum()
customer_revune=sales_df.groupby("Customer ID")['Revenue'].sum()
contribution_customer=((customer_revune/total_revune)*100)
contribution_customer=contribution_customer.sort_values(ascending=False)
print(contribution_customer)
# Out:
# Customer ID
# 18102.0    3.399264
# 14646.0    2.418246
# 14156.0    1.913496
# 14911.0    1.480965
# 13694.0    1.279656
#              ...
# 18115.0    0.000094
# 15040.0    0.000073
# 15913.0    0.000061
# 13788.0    0.000037
# 14095.0    0.000029
# Name: Revenue, Length: 4312, dtype: float64

# %%
# Find the top 10 customers by number of products purchased.
products_per_customer = (
    sales_df.groupby("Customer ID")["Description"]
    .nunique()
    .sort_values(ascending=False)
)
products_per_customer
# Out:
# Customer ID
# 14911.0    1862
# 17841.0    1579
# 12748.0    1380
# 14156.0    1178
# 14606.0    1163
#            ...
# 17378.0       1
# 16990.0       1
# 15233.0       1
# 12362.0       1
# 18246.0       1
# Name: Description, Length: 4312, dtype: int64

# %%
# Find the average order value for each customer.
customer_aov = (
    sales_df.groupby(["Customer ID", "Invoice"])["Revenue"]
    .sum()
    .groupby("Customer ID")
    .mean()
)
customer_aov
# Out:
# Customer ID
# 12346.0     33.896364
# 12347.0    661.660000
# 12348.0    222.160000
# 12349.0    890.380000
# 12351.0    300.930000
#               ...
# 18283.0    103.228333
# 18284.0    461.680000
# 18285.0    427.000000
# 18286.0    648.215000
# 18287.0    586.427500
# Name: Revenue, Length: 4312, dtype: float64

# %%
# Identify high-value customers.
customer_spending=sales_df.groupby("Customer ID")['Revenue'].sum()
high_value_customers = customer_spending[
    customer_spending >= customer_spending.quantile(0.90)
]

print(high_value_customers)
# Out:
# Customer ID
# 12357.0    12079.99
# 12380.0     6951.49
# 12409.0    12346.62
# 12415.0    19543.84
# 12422.0     4428.24
#              ...
# 18225.0     7539.84
# 18226.0     6650.83
# 18231.0     4782.40
# 18251.0    21964.14
# 18260.0     7318.91
# Name: Revenue, Length: 432, dtype: float64

# %%
# Compare custome
country_customer_spending = (
sales_df.groupby("Country")["Revenue"]
    .sum()
    .sort_values(ascending=False)
)
country_customer_spending
# Out:
# Country
# United Kingdom          8812311.833
# EIRE                     380909.570
# Netherlands              268784.350
# Germany                  202025.391
# France                   147103.140
# Sweden                    53501.990
# Denmark                   50906.850
# Spain                     47568.650
# Switzerland               43921.390
# Australia                 31446.800
# Channel Islands           24546.320
# Belgium                   24537.580
# Portugal                  24265.000
# Norway                    23944.180
# Italy                     15052.730
# Greece                    14335.670
# Austria                   13414.330
# Cyprus                    11347.100
# Japan                      9722.020
# United Arab Emirates       9195.350
# Hong Kong                  8202.520
# Finland                    7379.460
# Unspecified                6186.220
# Malta                      5373.500
# Lithuania                  4892.680
# USA                        4786.470
# ...

# %% [markdown]
#  Time Analysis

# %%
sales_df["Year"] = sales_df["InvoiceDate"].dt.year
print(sales_df['Year'])
sales_df["Month"] = sales_df["InvoiceDate"].dt.month
print(sales_df['Month'])
sales_df["Month_Name"] = sales_df["InvoiceDate"].dt.strftime("%B")
print(sales_df['Month_Name'])
sales_df["Date"] = sales_df["InvoiceDate"].dt.date
print(sales_df['Date'])
sales_df["Day"] = sales_df["InvoiceDate"].dt.day_name()
print(sales_df["Day"] )
# Out:
# 0         2009
# 1         2009
# 2         2009
# 3         2009
# 4         2009
#           ...
# 525456    2010
# 525457    2010
# 525458    2010
# 525459    2010
# 525460    2010
# Name: Year, Length: 504730, dtype: int32
# 0         12
# 1         12
# 2         12
# 3         12
# 4         12
#           ..
# 525456    12
# 525457    12
# 525458    12
# 525459    12
# 525460    12
# Name: Month, Length: 504730, dtype: int32
# 0         December
# 1         December
# 2         December
# 3         December
# 4         December
#             ...
# 525456    December
# 525457    December
# 525458    December
# 525459    December
# 525460    December
# Name: Month_Name, Length: 504730, dtype: object
# 0         2009-12-01
# 1         2009-12-01
# 2         2009-12-01
# 3         2009-12-01
# 4         2009-12-01
#              ...
# 525456    2010-12-09
# 525457    2010-12-09
# 525458    2010-12-09
# 525459    2010-12-09
# 525460    2010-12-09
# ...

# %%
# Calculate monthly revenue.
monthly_revune=sales_df.groupby(sales_df['InvoiceDate'].dt.to_period("M"))['Revenue'].sum()
monthly_revune
# Out:
# InvoiceDate
# 2009-12     822483.950
# 2010-01     651155.112
# 2010-02     551504.726
# 2010-03     830915.261
# 2010-04     678875.252
# 2010-05     657705.500
# 2010-06     749537.310
# 2010-07     648810.270
# 2010-08     695251.910
# 2010-09     921696.991
# 2010-10    1161902.220
# 2010-11    1464293.142
# 2010-12     437631.020
# Freq: M, Name: Revenue, dtype: float64

# %%
# Calculate monthly quantity sold.
monthly_sold=sales_df.groupby(sales_df['InvoiceDate'].dt.to_period('M'))['Quantity'].sum()
monthly_sold
# Out:
# InvoiceDate
# 2009-12    425461
# 2010-01    390672
# 2010-02    381879
# 2010-03    526026
# 2010-04    366705
# 2010-05    395868
# 2010-06    406820
# 2010-07    337895
# 2010-08    472380
# 2010-09    583864
# 2010-10    619996
# 2010-11    725161
# 2010-12    180220
# Freq: M, Name: Quantity, dtype: int64

# %%
# Calculate monthly number of orders.
montly_orders=sales_df.groupby(sales_df['InvoiceDate'].dt.to_period('M'))['Invoice'].nunique()
montly_orders
# Out:
# InvoiceDate
# 2009-12    1682
# 2010-01    1105
# 2010-02    1201
# 2010-03    1681
# 2010-04    1462
# 2010-05    1500
# 2010-06    1645
# 2010-07    1529
# 2010-08    1425
# 2010-09    1839
# 2010-10    2301
# 2010-11    2747
# 2010-12     834
# Freq: M, Name: Invoice, dtype: int64

# %%
df.columns
# Out:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country', 'Cancelled', 'Revenue'],
#       dtype='object')

# %%
# Find the highest-revenue month.
monthly_revune=sales_df.groupby(sales_df['InvoiceDate'].dt.to_period("M"))['Revenue'].sum()
highest_revune=monthly_revune.sort_values(ascending=False).head(1)
highest_revune
# Out:
# InvoiceDate
# 2010-11    1464293.142
# Freq: M, Name: Revenue, dtype: float64

# %%
# Find the highest-revenue month.
monthly_revune=sales_df.groupby(sales_df['InvoiceDate'].dt.to_period("M"))['Revenue'].sum()
lowest_revune=monthly_revune.sort_values(ascending=True).head(1)
lowest_revune
# Out:
# InvoiceDate
# 2010-12    437631.02
# Freq: M, Name: Revenue, dtype: float64

# %%
  # Calculate daily revenue.
daily_revue=sales_df.groupby("Date")['Revenue'].sum()
print(daily_revue)
# Out:
# Date
# 2009-12-01    54351.23
# 2009-12-02    63172.58
# 2009-12-03    73972.45
# 2009-12-04    40582.32
# 2009-12-05     9803.05
#                 ...
# 2010-12-05    31364.63
# 2010-12-06    54624.15
# 2010-12-07    99553.85
# 2010-12-08    45235.36
# 2010-12-09    53548.19
# Name: Revenue, Length: 307, dtype: float64

# %%
# Find the highest-revenue day.

daily_revue=sales_df.groupby("Date")['Revenue'].sum()
highest_revenue_day=daily_revue.sort_values(ascending=False).head(1)
highest_revenue_day
# Out:
# Date
# 2010-09-27    118838.47
# Name: Revenue, dtype: float64

# %%
# Find the lowest-revenue day..
daily_revue=sales_df.groupby("Date")['Revenue'].sum()
lowest_revenue_day=daily_revue.sort_values(ascending=True).head(1)
lowest_revenue_day
# Out:
# Date
# 2010-07-11    7784.95
# Name: Revenue, dtype: float64

# %%
# Calculate average daily revenue.
avg_daily_revue=sales_df.groupby("Date")['Revenue'].mean()
avg_daily_revue
# Out:
# Date
# 2009-12-01    17.715525
# 2009-12-02    19.692201
# 2009-12-03    25.237956
# 2009-12-04    16.370440
# 2009-12-05    24.507625
#                 ...
# 2010-12-05    12.049416
# 2010-12-06    14.496855
# 2010-12-07    34.980271
# 2010-12-08    17.907902
# 2010-12-09    19.366434
# Name: Revenue, Length: 307, dtype: float64

# %%
# Calculate revenue by year.
year_revune=sales_df.groupby("Year")['Revenue'].sum()
year_revune
# Out:
# Year
# 2009     822483.950
# 2010    9449278.714
# Name: Revenue, dtype: float64

# %%
# Compare yearly revenue.
year_revune=sales_df.groupby("Year")['Revenue'].sum()
year_revune=year_revune.sort_values(ascending=False)
year_revune
# Out:
# Year
# 2010    9449278.714
# 2009     822483.950
# Name: Revenue, dtype: float64

# %%
# Calculate revenue by day of the week.
weekday_revenue = sales_df.groupby("Day")["Revenue"].sum()
print(weekday_revenue)
# Out:
# Day
# Friday       1533319.022
# Monday       1860436.255
# Saturday        9803.050
# Sunday       1023721.131
# Thursday     2097097.802
# Tuesday      2002003.301
# Wednesday    1745382.103
# Name: Revenue, dtype: float64

# %%
# Find the best-performing weekday.
weekday_revenue = sales_df.groupby("Day")["Revenue"].sum()
weekday_revenue_best=weekday_revenue.sort_values(ascending=False).head(1)
weekday_revenue_best
# Out:
# Day
# Thursday    2097097.802
# Name: Revenue, dtype: float64

# %%
# Find the worst-performing weekday.
weekday_revenue = sales_df.groupby("Day")["Revenue"].sum()
weekday_revenue_wrost=weekday_revenue.sort_values(ascending=True).head(1)
weekday_revenue_wrost
# Out:
# Day
# Saturday    9803.05
# Name: Revenue, dtype: float64

# %%
# Analyze monthly order trends.
montly_orders=sales_df.groupby(sales_df['InvoiceDate'].dt.to_period('M'))['Invoice'].nunique()
montly_orders_anlysis=montly_orders.sort_values(ascending=False)
montly_orders_anlysis
# Out:
# InvoiceDate
# 2010-11    2747
# 2010-10    2301
# 2010-09    1839
# 2009-12    1682
# 2010-03    1681
# 2010-06    1645
# 2010-07    1529
# 2010-05    1500
# 2010-04    1462
# 2010-08    1425
# 2010-02    1201
# 2010-01    1105
# 2010-12     834
# Freq: M, Name: Invoice, dtype: int64

# %% [markdown]
# countery analysis

# %%
# Calculate total revenue by country.
country_revenue=sales_df.groupby("Country")['Revenue'].sum()
country_revenue
# Out:
# Country
# Australia                 31446.800
# Austria                   13414.330
# Bahrain                    2355.650
# Belgium                   24537.580
# Bermuda                    1253.140
# Brazil                      268.270
# Canada                     1216.660
# Channel Islands           24546.320
# Cyprus                    11347.100
# Denmark                   50906.850
# EIRE                     380909.570
# Finland                    7379.460
# France                   147103.140
# Germany                  202025.391
# Greece                    14335.670
# Hong Kong                  8202.520
# Iceland                    1323.320
# Israel                     3199.400
# Italy                     15052.730
# Japan                      9722.020
# Korea                      1118.510
# Lebanon                     211.700
# Lithuania                  4892.680
# Malta                      5373.500
# Netherlands              268784.350
# Nigeria                     140.390
# ...

# %%
# Find the top 10 countries by revenue.
country_revenue=sales_df.groupby("Country")['Revenue'].sum()
top10_country=country_revenue.sort_values(ascending=False).head(10)
top10_country
# Out:
# Country
# United Kingdom    8812311.833
# EIRE               380909.570
# Netherlands        268784.350
# Germany            202025.391
# France             147103.140
# Sweden              53501.990
# Denmark             50906.850
# Spain               47568.650
# Switzerland         43921.390
# Australia           31446.800
# Name: Revenue, dtype: float64

# %%
df.columns
# Out:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country', 'Cancelled', 'Revenue'],
#       dtype='object')

# %%
# Find the country with the highest number of orders.
country_orders=sales_df.groupby("Country")['Invoice'].count()
top_order_country=country_orders.sort_values(ascending=False).head(1)
top_order_country
# Out:
# Country
# United Kingdom    466602
# Name: Invoice, dtype: int64

# %%
# Find the country with the highest quantity sold.
country_quantity=sales_df.groupby("Country")['Quantity'].sum()
top_quantity_country=country_quantity.sort_values(ascending=False).head(1)
top_quantity_country
# Out:
# Country
# United Kingdom    4702280
# Name: Quantity, dtype: int64

# %%
# Calculate average order value by country.
country_aov = (
    sales_df.groupby(["Country", "Invoice"])["Revenue"]
    .sum()
    .groupby("Country")
    .mean()
    .sort_values(ascending=False)
)

print(country_aov)
# Out:
# Country
# Norway                  2176.743636
# Hong Kong               2050.630000
# Netherlands             1990.995185
# Denmark                 1957.955769
# Israel                  1599.700000
# Thailand                1535.270000
# Malta                   1343.375000
# RSA                     1267.336667
# Bermuda                 1253.140000
# Greece                  1102.743846
# Switzerland             1098.034750
# EIRE                    1094.567730
# Singapore               1009.442500
# Channel Islands          818.210667
# Lithuania                815.446667
# Australia                786.170000
# Sweden                   775.391159
# Spain                    720.737121
# United Arab Emirates     707.334615
# Iceland                  661.660000
# France                   610.386473
# Canada                   608.330000
# Japan                    607.626250
# Portugal                 591.829268
# Germany                  582.205738
# Unspecified              562.383636
# ...

# %%
# Find countries with revenue above average.
avg_country_revenue = country_revenue.mean()

print(
    country_revenue[
        country_revenue > avg_country_revenue
    ]
)
# Out:
# Country
# EIRE               380909.570
# Netherlands        268784.350
# United Kingdom    8812311.833
# Name: Revenue, dtype: float64

# %%
# Calculate each country's percentage contribution to total revenue.
country_percentage = (
    country_revenue / country_revenue.sum() * 100
)

print(country_percentage)
# Out:
# Country
# Australia                0.306148
# Austria                  0.130594
# Bahrain                  0.022933
# Belgium                  0.238884
# Bermuda                  0.012200
# Brazil                   0.002612
# Canada                   0.011845
# Channel Islands          0.238969
# Cyprus                   0.110469
# Denmark                  0.495600
# EIRE                     3.708317
# Finland                  0.071842
# France                   1.432112
# Germany                  1.966804
# Greece                   0.139564
# Hong Kong                0.079855
# Iceland                  0.012883
# Israel                   0.031148
# Italy                    0.146545
# Japan                    0.094648
# Korea                    0.010889
# Lebanon                  0.002061
# Lithuania                0.047632
# Malta                    0.052313
# Netherlands              2.616731
# Nigeria                  0.001367
# Norway                   0.233107
# ...

# %%
# Compare customer counts by country.
country_customers = (
    sales_df.groupby("Country")["Customer ID"]
    .nunique()
    .sort_values(ascending=False)
)

print(country_customers)
# Out:
# Country
# United Kingdom          3969
# Germany                   67
# France                    47
# Spain                     25
# Netherlands               22
# Portugal                  18
# Belgium                   17
# Sweden                    16
# Australia                 15
# Switzerland               14
# Italy                     11
# Channel Islands           11
# Austria                   10
# Denmark                    9
# Finland                    7
# Cyprus                     7
# Japan                      6
# USA                        6
# Norway                     5
# EIRE                       5
# Unspecified                4
# United Arab Emirates       4
# Greece                     4
# Bahrain                    2
# Israel                     2
# Korea                      2
# Poland                     2
# Brazil                     1
# Singapore                  1
# Canada                     1
# Iceland                    1
# ...

# %%
# Find the country with the highest average customer spending.
avg_customer_country = (
    sales_df.groupby(["Country", "Customer ID"])["Revenue"]
    .sum()
    .groupby("Country")
    .mean()
    .sort_values(ascending=False)
)

print(avg_customer_country.head(1))
# Out:
# Country
# EIRE    71208.372
# Name: Revenue, dtype: float64

# %%
# 80. Customers vs revenue by country
country_analysis = pd.DataFrame({
    "Customers": country_customers,
    "Revenue": country_revenue
}).sort_values("Revenue", ascending=False)

print(country_analysis)
# Out:
#                       Customers      Revenue
# Country
# United Kingdom             3969  8812311.833
# EIRE                          5   380909.570
# Netherlands                  22   268784.350
# Germany                      67   202025.391
# France                       47   147103.140
# Sweden                       16    53501.990
# Denmark                       9    50906.850
# Spain                        25    47568.650
# Switzerland                  14    43921.390
# Australia                    15    31446.800
# Channel Islands              11    24546.320
# Belgium                      17    24537.580
# Portugal                     18    24265.000
# Norway                        5    23944.180
# Italy                        11    15052.730
# Greece                        4    14335.670
# Austria                      10    13414.330
# Cyprus                        7    11347.100
# Japan                         6     9722.020
# United Arab Emirates          4     9195.350
# ...

# %%
# Calculate revenue using Quantity × UnitPrice.
revune=df["Price"]*df['Quantity']
revune
# Out:
# 0          83.40
# 1          81.00
# 2          81.00
# 3         100.80
# 4          30.00
#            ...
# 525456      5.90
# 525457      3.75
# 525458      3.75
# 525459      7.50
# 525460      3.90
# Length: 518596, dtype: float64

# %%
# Identify cancelled transactions.
cancelled=df[df['Cancelled']]
print(cancelled.head(4))
# Out:
#      Invoice StockCode                    Description  Quantity  \
# 178  C489449     22087       PAPER BUNTING WHITE LACE       -12
# 179  C489449    85206A   CREAM FELT EASTER EGG BASKET        -6
# 180  C489449     21895  POTTING SHED SOW 'N' GROW SET        -4
# 181  C489449     21896             POTTING SHED TWINE        -6
#
#             InvoiceDate  Price  Customer ID    Country  Cancelled  Revenue
# 178 2009-12-01 10:33:00   2.95      16321.0  Australia       True    -35.4
# 179 2009-12-01 10:33:00   1.65      16321.0  Australia       True     -9.9
# 180 2009-12-01 10:33:00   4.25      16321.0  Australia       True    -17.0
# 181 2009-12-01 10:33:00   2.10      16321.0  Australia       True    -12.6

# %%
# Calculate cancellation rate.
cancellation_rate = (
    df["Cancelled"].mean() * 100
)
print(cancellation_rate)
# Out:
# 1.96337804379517

# %%
# Compare cancelled and completed orders.
order_status = df.groupby("Cancelled")["Invoice"].nunique()
print(order_status)
# Out:
# Cancelled
# False    24224
# True      4592
# Name: Invoice, dtype: int64

# %%
# Find products with the highest cancellation quantities.
cancellation_quantity=df.groupby("Description")['Quantity'].sum()
cancellation_quantity_highest=abs(cancellation_quantity).sort_values(ascending=False).head(10)
cancellation_quantity_highest
# Out:
# Description
# WHITE HANGING HEART T-LIGHT HOLDER    57632
# WORLD WAR 2 GLIDERS ASSTD DESIGNS     54554
# BROCADE RING PURSE                    47647
# PACK OF 72 RETRO SPOT CAKE CASES      46079
# ASSORTED COLOUR BIRD ORNAMENT         44805
# 60 TEATIME FAIRY CAKE CASES           36172
# PACK OF 60 PINK PAISLEY CAKE CASES    31687
# JUMBO BAG RED RETROSPOT               30668
# SMALL POPCORN HOLDER                  29485
# STRAWBERRY CERAMIC TRINKET BOX        26496
# Name: Quantity, dtype: int64

# %%
# Calculate customer lifetime spending.
life_time_value=df.groupby('Customer ID')['Revenue'].sum()
life_time_value.sort_values(ascending=False)
# Out:
# Customer ID
# 18102.0    341776.73
# 14646.0    243853.05
# 14156.0    183163.55
# 14911.0    137710.76
# 13694.0    128172.42
#              ...
# 16981.0     -4620.86
# 15760.0     -5795.87
# 15849.0     -5876.34
# 12918.0    -10953.50
# 17399.0    -25111.09
# Name: Revenue, Length: 4383, dtype: float64

# %%
df.columns
# Out:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country', 'Cancelled', 'Revenue'],
#       dtype='object')

# %%
# Rank customers based on revenue.
customer_revenue=df.groupby('Customer ID')['Revenue'].sum()
rank=customer_revenue.rank(method='dense',ascending=False)
top_rank=pd.DataFrame({"Customer_Revenue":customer_revenue,
                       'Rank':rank}).sort_values('Rank').head(10)
top_rank
# Out:
#              Customer_Revenue  Rank
# Customer ID
# 18102.0             341776.73   1.0
# 14646.0             243853.05   2.0
# 14156.0             183163.55   3.0
# 14911.0             137710.76   4.0
# 13694.0             128172.42   5.0
# 17511.0              83760.60   6.0
# 15061.0              82162.74   7.0
# 16684.0              75610.17   8.0
# 13089.0              55801.73   9.0
# 16754.0              54558.18  10.0

# %%
# Rank products based on revenue
product_revune=df.groupby("StockCode")['Revenue'].sum()
rank=product_revune.rank(method='dense',ascending=False)
ranking_products=pd.DataFrame({'product_id':product_revune,
                               'Rank':rank}).sort_values('Rank')
ranking_products
# Out:
#               product_id    Rank
# StockCode
# 22423          162885.71     1.0
# 85123A         155540.37     2.0
# DOT            116401.99     3.0
# 85099B          88784.03     4.0
# 84879           72251.32     5.0
# ...                  ...     ...
# D               -7788.32  4043.0
# M              -14137.84  4044.0
# BANK CHARGES   -28386.99  4045.0
# AMAZONFEE      -39243.08  4046.0
# B             -136552.02  4047.0
#
# [4632 rows x 2 columns]

# %%
# Calculate monthly revenue growth
monthly_revune=df.groupby(sales_df['InvoiceDate'].dt.to_period("M"))['Revenue'].sum()
revune_growth=monthly_revune.pct_change()*100
revune_growth
# Out:
# InvoiceDate
# 2009-12          NaN
# 2010-01   -20.830660
# 2010-02   -15.303633
# 2010-03    50.663307
# 2010-04   -18.297896
# 2010-05    -3.118357
# 2010-06    13.962451
# 2010-07   -13.438563
# 2010-08     7.157969
# 2010-09    32.570221
# 2010-10    26.061193
# 2010-11    26.025505
# 2010-12   -70.113155
# Freq: M, Name: Revenue, dtype: float64

# %%
# Calculate the percentage change in monthly revenue.
monthly_percentage_change = monthly_revune.pct_change() * 100
print(monthly_percentage_change)
# Out:
# InvoiceDate
# 2009-12          NaN
# 2010-01   -20.830660
# 2010-02   -15.303633
# 2010-03    50.663307
# 2010-04   -18.297896
# 2010-05    -3.118357
# 2010-06    13.962451
# 2010-07   -13.438563
# 2010-08     7.157969
# 2010-09    32.570221
# 2010-10    26.061193
# 2010-11    26.025505
# 2010-12   -70.113155
# Freq: M, Name: Revenue, dtype: float64

# %%
# Calculate a 3-month moving amonverage of revenue.
moving_avg_3__months=monthly_revune.rolling(3).mean()
moving_avg_3__months
# Out:
# InvoiceDate
# 2009-12             NaN
# 2010-01             NaN
# 2010-02    6.750479e+05
# 2010-03    6.778584e+05
# 2010-04    6.870984e+05
# 2010-05    7.224987e+05
# 2010-06    6.953727e+05
# 2010-07    6.853510e+05
# 2010-08    6.978665e+05
# 2010-09    7.552531e+05
# 2010-10    9.262837e+05
# 2010-11    1.182631e+06
# 2010-12    1.021275e+06
# Freq: M, Name: Revenue, dtype: float64

# %%
df.columns
# Out:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country', 'Cancelled', 'Revenue'],
#       dtype='object')

# %%
# Find the top 3 products for each country.
country_product = (
    sales_df.groupby(["Country", "Description"])["Revenue"]
    .sum()
    .reset_index()
)

country_product["Rank"] = (
    country_product.groupby("Country")["Revenue"]
    .rank(method="dense", ascending=False)
)

top_3_country_products = country_product[
    country_product["Rank"] <= 3
].sort_values(["Country", "Rank"])

print(top_3_country_products)
# Out:
#            Country                         Description  Revenue  Rank
# 225      Australia                              Manual  1133.45   1.0
# 324      Australia            REGENCY CAKESTAND 3 TIER   952.50   2.0
# 311      Australia       RED RETROSPOT ROUND CAKE TINS   546.95   3.0
# 693        Austria                             POSTAGE  1600.00   1.0
# 563        Austria           EDWARDIAN PARASOL NATURAL   439.80   2.0
# ...            ...                                 ...      ...   ...
# 19206  Unspecified         LARGE CAKE TOWEL PINK SPOTS   162.00   3.0
# 19361  West Indies             BOX OF 9 PEBBLE CANDLES    46.80   1.0
# 19368  West Indies       GROW YOUR OWN PLANT IN A CAN     30.00   2.0
# 19374  West Indies  OCEAN SCENT CANDLE IN JEWELLED BOX    25.50   3.0
# 19380  West Indies   ROSE SCENT CANDLE IN JEWELLED BOX    25.50   3.0
#
# [135 rows x 4 columns]

# %%
# Find the top 5 customers for each country.
customer_country=(df.groupby(['Customer ID','Country'])['Revenue'].sum().reset_index())
customer_country['Rank']=(customer_country.groupby("Country")['Revenue'].rank(method='dense',ascending=False))
top_5_customer=customer_country[customer_country['Rank']<=5].sort_values(['Country','Rank'])
print(top_5_customer)
# Out:
#       Customer ID      Country   Revenue  Rank
# 51        12415.0    Australia  19543.84   1.0
# 67        12431.0    Australia   2543.37   2.0
# 62        12424.0    Australia   1528.82   3.0
# 32        12389.0    Australia   1433.33   4.0
# 58        12422.0    Australia   1363.45   5.0
# ...           ...          ...       ...   ...
# 1380      14265.0  Unspecified    843.17   2.0
# 4         12351.0  Unspecified    300.93   3.0
# 91        12470.0  Unspecified    211.95   4.0
# 2198      15357.0  Unspecified    -36.75   5.0
# 4283      18140.0  West Indies    536.41   1.0
#
# [131 rows x 4 columns]

# %%
#Identify customers who purchased in multiple months.
customer_months = (
    sales_df.assign(
        YearMonth=sales_df["InvoiceDate"].dt.to_period("M")
    )
    .groupby("Customer ID")["YearMonth"]
    .nunique()
)

print(customer_months[customer_months > 1])
# Out:
# Customer ID
# 12346.0    4
# 12347.0    2
# 12349.0    3
# 12356.0    2
# 12358.0    3
#           ..
# 18276.0    5
# 18277.0    3
# 18283.0    4
# 18286.0    2
# 18287.0    3
# Name: YearMonth, Length: 2721, dtype: int64

# %%
# Identify customers who purchased multiple times.
customer_purchase_count = (
    sales_df.groupby("Customer ID")["Invoice"]
    .nunique()
)

print(customer_purchase_count[
    customer_purchase_count > 1
])
# Out:
# Customer ID
# 12346.0    11
# 12347.0     2
# 12349.0     3
# 12352.0     2
# 12356.0     3
#            ..
# 18276.0     5
# 18277.0     4
# 18283.0     6
# 18286.0     2
# 18287.0     4
# Name: Invoice, Length: 2893, dtype: int64

# %%
# Calculate customer purchase frequency.
purchase_frequency = (
    sales_df.groupby("Customer ID")["Invoice"]
    .nunique()
)

print(purchase_frequency.sort_values(ascending=False))
# Out:
# Customer ID
# 14911.0    205
# 17850.0    155
# 12748.0    144
# 15311.0    121
# 13089.0    109
#           ...
# 18254.0      1
# 18253.0      1
# 18246.0      1
# 18243.0      1
# 12392.0      1
# Name: Invoice, Length: 4312, dtype: int64

# %%
# Segment customers based on spending.
customer_segment = pd.qcut(
    customer_spending,
    q=4,
    labels=["Low", "Medium", "High", "VIP"]
)

print(customer_segment.value_counts())
# Out:
# Revenue
# Low       1078
# Medium    1078
# High      1078
# VIP       1078
# Name: count, dtype: int64

# %%
# Analyze the relationship between quantity and revenue.
correlation = sales_df[
    ["Quantity", "Revenue"]
].corr()

print(correlation)
# Out:
#           Quantity   Revenue
# Quantity  1.000000  0.325073
# Revenue   0.325073  1.000000

# %%
# Identify the most important products, customers, countries, and months driving overall revenue
print("Top Products:")
print(product_revune.sort_values(ascending=False).head(10))
print("\nTop Customers:")
print(customer_spending.head(10))
print("\nTop Countries:")
print(country_revenue.head(10))
print("\nTop Months:")
print(monthly_revune.sort_values(ascending=False).head(10))
# Out:
# Top Products:
# StockCode
# 22423     162885.71
# 85123A    155540.37
# DOT       116401.99
# 85099B     88784.03
# 84879      72251.32
# 22086      57808.25
# 47566      49626.92
# 84347      47641.89
# POST       46092.36
# 21843      42073.15
# Name: Revenue, dtype: float64
#
# Top Customers:
# Customer ID
# 12346.0      372.86
# 12347.0     1323.32
# 12348.0      222.16
# 12349.0     2671.14
# 12351.0      300.93
# 12352.0      343.80
# 12353.0      317.76
# 12355.0      488.21
# 12356.0     3560.30
# 12357.0    12079.99
# Name: Revenue, dtype: float64
#
# Top Countries:
# Country
# Australia          31446.80
# Austria            13414.33
# Bahrain             2355.65
# Belgium            24537.58
# Bermuda             1253.14
# Brazil               268.27
# Canada              1216.66
# Channel Islands    24546.32
# Cyprus             11347.10
# Denmark            50906.85
# Name: Revenue, dtype: float64
#
# Top Months:
# InvoiceDate
# 2010-11    1464293.142
# ...

# %% [markdown]
# VISUALS

# %%
import matplotlib.pyplot as plt
import  seaborn as sns

# %%
# Revenue by month
monthly_revenue=df.groupby(df['InvoiceDate'].dt.to_period("M"))['Revenue'].sum()
monthly_revenue.plot(kind='bar',figsize=(6,4),xlabel='MONTH_NAME',ylabel='REVUNE',title='REVENUE BY MONTH')
# Out:
# <Axes: title={'center': 'REVENUE BY MONTH'}, xlabel='MONTH_NAME', ylabel='REVUNE'>

# %%
df.columns
# Out:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country', 'Cancelled', 'Revenue'],
#       dtype='object')

# %%
# Top 10 products by revenue
product_revune=df.groupby("Description")['Revenue'].sum()
top10=prodcutrevune.sort_values(ascending=False).head(10)
top10.plot(kind='barh',figsize=(9,6),xlabel='REVENUE',ylabel='PRODUCTS',title='TOP10PRODUCTS BY REVUNE')

# %%
# Top 10 customers
customer_revenue=df.groupby('Customer ID')['Revenue'].sum()
top10=customer_revune.sort_values(ascending=False).head(10)
top10.plot(kind='bar',figsize=(7,5),xlabel='customer_id',ylabel='revune',title='top10 customer')
# Out:
# <Axes: title={'center': 'top10 customer'}, xlabel='customer_id', ylabel='revune'>

# %%
# Revenue by country
plt.figure(figsize=(10, 6))
country_revenue.head(10).sort_values(ascending=False).plot(kind="barh")
plt.title("Top 10 Countries by Revenue")
plt.xlabel("Revenue")
plt.ylabel("Country")
plt.tight_layout()
plt.show()

# %%
# Quantity by product
quantity_products=df.groupby("StockCode")['Quantity'].sum()
quantity_products.sort_values(ascending=False).head(5).plot(kind='bar',figsize=(7,5),xlabel='PRODUCT_ID',ylabel='QUANTITY',title='QUANTITY VS PRODUCT_ID')
# Out:
# <Axes: title={'center': 'QUANTITY VS PRODUCT_ID'}, xlabel='PRODUCT_ID', ylabel='QUANTITY'>

# %%
plt.figure(figsize=(8, 6))

plt.scatter(
    sales_df["Quantity"],
    sales_df["Revenue"],
    alpha=0.3
)

plt.title("Quantity vs Revenue")
plt.xlabel("Quantity")
plt.ylabel("Revenue")
plt.show()

# %%
# Daily revenue trend
daily_revue=sales_df.groupby("Date")['Revenue'].sum()
daily_revue.plot()
plt.title("Daily Revenue Trend")
plt.xlabel("Date")
plt.ylabel("Revenue")
plt.tight_layout()
plt.show()

# %%
# Customer spending distribution
customer_spend=sales_df.groupby("Customer ID")['Revenue'].sum()
plt.figure(figsize=(10, 6))
plt.hist(customer_spending, bins=50)
plt.title("Customer Spending Distribution")
plt.xlabel("Customer Spending")
plt.ylabel("Number of Customers")
plt.tight_layout()
plt.show()

# %%
# Cancellation analysis
cancellation_counts = df["Cancelled"].value_counts()
plt.figure(figsize=(7, 5))
cancellation_counts.plot(kind="bar")
plt.title("Cancellation Analysis")
plt.xlabel("Cancelled")
plt.ylabel("Number of Transactions")
plt.xticks(
    [0, 1],
    ["Completed", "Cancelled"],
    rotation=0
)
plt.tight_layout()
plt.show()
